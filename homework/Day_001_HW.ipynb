# %% [markdown]
# # Homework1

# %% [markdown]
# 請上Kaggle， 在Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# Dataset:Heart Disease UCI (https://www.kaggle.com/ronitf/heart-disease-uci)
# 1. Why this dataset important?
# >This dataset can help doctor to predict the chance of heard disease happend.
# 2. where is it come from?
# >The dataset is personal information with target zero/one, created by:
#     1. Hungarian Institute of Cardiology. Budapest: Andras Janosi, M.D.
#     2. University Hospital, Zurich, Switzerlan: William Steinbrunn, M.D.
#     3. University Hospital, Basel, Switzerlan: Matthias Pfisterer, M.D.
#     4. V.A. Medical Center, Long Beach and Cleveland Clinic Foundation: Robert Detrano, M.D., Ph.D.
# 3. what is it's datastructure?
# >It is csv data(structure data) which have 303 data with 13 attributes.
# 4. How to evaluate the problem?
# >AUC(ROC curve)

# %% [markdown]
# # Homework2

# %% [markdown]
# 想像你經營一個自由載客車隊，你希望透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# 1. 核心問題為何：
# >如何利用數據分析提高收入以及減少成本(時間與人力成本)，即優化車子的分佈還有載客路徑。
# 2. 資料從何而來：
# >載客上下車位置, 時間, 路徑,
# 3. 蒐集而來的資料型態為何：
# >結構化資料
# 4. 你要回答的問題，其如何評估：
# >計算一定期間內的淨利是否有提升

# %% [markdown]
# # Homework3

# %% [markdown]
# Mean Square Error
# >$ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# MAE Sample code
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

def mean_squared_error(y, y_hat):
    mse = sum(np.square(y - y_hat))/len(y)
    return mse

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 227.556
# The Mean absolute error is 11.400
